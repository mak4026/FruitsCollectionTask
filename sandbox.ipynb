# %%
from qLearning import QLearning
from field import Field
f = Field()
a =  QLearning(f)

a.qvalue
# Out:
# {(0, 0): {<Action.UP: (0, 1)>: 0.0, <Action.RIGHT: (1, 0)>: 0.0},
#  (0, 1): {<Action.UP: (0, 1)>: 0.0,
#   <Action.DOWN: (0, -1)>: 0.0,
#   <Action.RIGHT: (1, 0)>: 0.0},
#  (0, 2): {<Action.UP: (0, 1)>: 0.0,
#   <Action.DOWN: (0, -1)>: 0.0,
#   <Action.RIGHT: (1, 0)>: 0.0},
#  (0, 3): {<Action.UP: (0, 1)>: 0.0,
#   <Action.DOWN: (0, -1)>: 0.0,
#   <Action.RIGHT: (1, 0)>: 0.0},
#  (0, 4): {<Action.UP: (0, 1)>: 0.0,
#   <Action.DOWN: (0, -1)>: 0.0,
#   <Action.RIGHT: (1, 0)>: 0.0},
#  (0, 5): {<Action.UP: (0, 1)>: 0.0,
#   <Action.DOWN: (0, -1)>: 0.0,
#   <Action.RIGHT: (1, 0)>: 0.0},
#  (0, 6): {<Action.UP: (0, 1)>: 0.0,
#   <Action.DOWN: (0, -1)>: 0.0,
#   <Action.RIGHT: (1, 0)>: 0.0},
#  (0, 7): {<Action.UP: (0, 1)>: 0.0,
#   <Action.DOWN: (0, -1)>: 0.0,
#   <Action.RIGHT: (1, 0)>: 0.0},
#  (0, 8): {<Action.UP: (0, 1)>: 0.0,
#   <Action.DOWN: (0, -1)>: 0.0,
#   <Action.RIGHT: (1, 0)>: 0.0},
#  (0, 9): {<Action.DOWN: (0, -1)>: 0.0, <Action.RIGHT: (1, 0)>: 0.0},
#  (1, 0): {<Action.UP: (0, 1)>: 0.0,
#   <Action.LEFT: (-1, 0)>: 0.0,
#   <Action.RIGHT: (1, 0)>: 0.0},
#  (1, 1): {<Action.UP: (0, 1)>: 0.0,
#   <Action.DOWN: (0, -1)>: 0.0,
#   <Action.LEFT: (-1, 0)>: 0.0,
#   <Action.RIGHT: (1, 0)>: 0.0},
#  (1, 2): {<Action.UP: (0, 1)>: 0.0,
#   <Action.DOWN: (0, -1)>: 0.0,
#   <Action.LEFT: (-1, 0)>: 0.0,
#   <Action.RIGHT: (1, 0)>: 0.0},
#  (1, 3): {<Action.UP: (0, 1)>: 0.0,
#   <Action.DOWN: (0, -1)>: 0.0,
#   <Action.LEFT: (-1, 0)>: 0.0,
#   <Action.RIGHT: (1, 0)>: 0.0},
#  (1, 4): {<Action.UP: (0, 1)>: 0.0,
#   <Action.DOWN: (0, -1)>: 0.0,
#   <Action.LEFT: (-1, 0)>: 0.0,
#   <Action.RIGHT: (1, 0)>: 0.0},
#  (1, 5): {<Action.UP: (0, 1)>: 0.0,
#   <Action.DOWN: (0, -1)>: 0.0,
#   <Action.LEFT: (-1, 0)>: 0.0,
#   <Action.RIGHT: (1, 0)>: 0.0},
#  (1, 6): {<Action.UP: (0, 1)>: 0.0,
#   <Action.DOWN: (0, -1)>: 0.0,
#   <Action.LEFT: (-1, 0)>: 0.0,
#   <Action.RIGHT: (1, 0)>: 0.0},
#  (1, 7): {<Action.UP: (0, 1)>: 0.0,
#   <Action.DOWN: (0, -1)>: 0.0,
#   <Action.LEFT: (-1, 0)>: 0.0,
#   <Action.RIGHT: (1, 0)>: 0.0},
#  (1, 8): {<Action.UP: (0, 1)>: 0.0,
#   <Action.DOWN: (0, -1)>: 0.0,
#   <Action.LEFT: (-1, 0)>: 0.0,
#   <Action.RIGHT: (1, 0)>: 0.0},
#  (1, 9): {<Action.DOWN: (0, -1)>: 0.0,
#   <Action.LEFT: (-1, 0)>: 0.0,
#   <Action.RIGHT: (1, 0)>: 0.0},
#  (2, 0): {<Action.UP: (0, 1)>: 0.0,
#   <Action.LEFT: (-1, 0)>: 0.0,
#   <Action.RIGHT: (1, 0)>: 0.0},
#  (2, 1): {<Action.UP: (0, 1)>: 0.0,
#   <Action.DOWN: (0, -1)>: 0.0,
#   <Action.LEFT: (-1, 0)>: 0.0,
#   <Action.RIGHT: (1, 0)>: 0.0},
#  (2, 2): {<Action.UP: (0, 1)>: 0.0,
#   <Action.DOWN: (0, -1)>: 0.0,
#   <Action.LEFT: (-1, 0)>: 0.0,
#   <Action.RIGHT: (1, 0)>: 0.0},
#  (2, 3): {<Action.UP: (0, 1)>: 0.0,
#   <Action.DOWN: (0, -1)>: 0.0,
#   <Action.LEFT: (-1, 0)>: 0.0,
#   <Action.RIGHT: (1, 0)>: 0.0},
#  (2, 4): {<Action.UP: (0, 1)>: 0.0,
#   <Action.DOWN: (0, -1)>: 0.0,
#   <Action.LEFT: (-1, 0)>: 0.0,
#   <Action.RIGHT: (1, 0)>: 0.0},
#  (2, 5): {<Action.UP: (0, 1)>: 0.0,
#   <Action.DOWN: (0, -1)>: 0.0,
#   <Action.LEFT: (-1, 0)>: 0.0,
#   <Action.RIGHT: (1, 0)>: 0.0},
#  (2, 6): {<Action.UP: (0, 1)>: 0.0,
#   <Action.DOWN: (0, -1)>: 0.0,
#   <Action.LEFT: (-1, 0)>: 0.0,
#   <Action.RIGHT: (1, 0)>: 0.0},
#  (2, 7): {<Action.UP: (0, 1)>: 0.0,
#   <Action.DOWN: (0, -1)>: 0.0,
#   <Action.LEFT: (-1, 0)>: 0.0,
#   <Action.RIGHT: (1, 0)>: 0.0},
#  (2, 8): {<Action.UP: (0, 1)>: 0.0,
#   <Action.DOWN: (0, -1)>: 0.0,
#   <Action.LEFT: (-1, 0)>: 0.0,
#   <Action.RIGHT: (1, 0)>: 0.0},
#  (2, 9): {<Action.DOWN: (0, -1)>: 0.0,
#   <Action.LEFT: (-1, 0)>: 0.0,
#   <Action.RIGHT: (1, 0)>: 0.0},
#  (3, 0): {<Action.UP: (0, 1)>: 0.0,
#   <Action.LEFT: (-1, 0)>: 0.0,
#   <Action.RIGHT: (1, 0)>: 0.0},
#  (3, 1): {<Action.UP: (0, 1)>: 0.0,
#   <Action.DOWN: (0, -1)>: 0.0,
#   <Action.LEFT: (-1, 0)>: 0.0,
#   <Action.RIGHT: (1, 0)>: 0.0},
#  (3, 2): {<Action.UP: (0, 1)>: 0.0,
#   <Action.DOWN: (0, -1)>: 0.0,
#   <Action.LEFT: (-1, 0)>: 0.0,
#   <Action.RIGHT: (1, 0)>: 0.0},
#  (3, 3): {<Action.UP: (0, 1)>: 0.0,
#   <Action.DOWN: (0, -1)>: 0.0,
#   <Action.LEFT: (-1, 0)>: 0.0,
#   <Action.RIGHT: (1, 0)>: 0.0},
#  (3, 4): {<Action.UP: (0, 1)>: 0.0,
#   <Action.DOWN: (0, -1)>: 0.0,
#   <Action.LEFT: (-1, 0)>: 0.0,
#   <Action.RIGHT: (1, 0)>: 0.0},
#  (3, 5): {<Action.UP: (0, 1)>: 0.0,
#   <Action.DOWN: (0, -1)>: 0.0,
#   <Action.LEFT: (-1, 0)>: 0.0,
#   <Action.RIGHT: (1, 0)>: 0.0},
#  (3, 6): {<Action.UP: (0, 1)>: 0.0,
#   <Action.DOWN: (0, -1)>: 0.0,
#   <Action.LEFT: (-1, 0)>: 0.0,
#   <Action.RIGHT: (1, 0)>: 0.0},
#  (3, 7): {<Action.UP: (0, 1)>: 0.0,
#   <Action.DOWN: (0, -1)>: 0.0,
#   <Action.LEFT: (-1, 0)>: 0.0,
#   <Action.RIGHT: (1, 0)>: 0.0},
#  (3, 8): {<Action.UP: (0, 1)>: 0.0,
#   <Action.DOWN: (0, -1)>: 0.0,
#   <Action.LEFT: (-1, 0)>: 0.0,
#   <Action.RIGHT: (1, 0)>: 0.0},
#  (3, 9): {<Action.DOWN: (0, -1)>: 0.0,
#   <Action.LEFT: (-1, 0)>: 0.0,
#   <Action.RIGHT: (1, 0)>: 0.0},
#  (4, 0): {<Action.UP: (0, 1)>: 0.0,
#   <Action.LEFT: (-1, 0)>: 0.0,
#   <Action.RIGHT: (1, 0)>: 0.0},
#  (4, 1): {<Action.UP: (0, 1)>: 0.0,
#   <Action.DOWN: (0, -1)>: 0.0,
#   <Action.LEFT: (-1, 0)>: 0.0,
#   <Action.RIGHT: (1, 0)>: 0.0},
#  (4, 2): {<Action.UP: (0, 1)>: 0.0,
#   <Action.DOWN: (0, -1)>: 0.0,
#   <Action.LEFT: (-1, 0)>: 0.0,
#   <Action.RIGHT: (1, 0)>: 0.0},
#  (4, 3): {<Action.UP: (0, 1)>: 0.0,
#   <Action.DOWN: (0, -1)>: 0.0,
#   <Action.LEFT: (-1, 0)>: 0.0,
#   <Action.RIGHT: (1, 0)>: 0.0},
#  (4, 4): {<Action.UP: (0, 1)>: 0.0,
#   <Action.DOWN: (0, -1)>: 0.0,
#   <Action.LEFT: (-1, 0)>: 0.0,
#   <Action.RIGHT: (1, 0)>: 0.0},
#  (4, 5): {<Action.UP: (0, 1)>: 0.0,
#   <Action.DOWN: (0, -1)>: 0.0,
#   <Action.LEFT: (-1, 0)>: 0.0,
#   <Action.RIGHT: (1, 0)>: 0.0},
#  (4, 6): {<Action.UP: (0, 1)>: 0.0,
#   <Action.DOWN: (0, -1)>: 0.0,
#   <Action.LEFT: (-1, 0)>: 0.0,
#   <Action.RIGHT: (1, 0)>: 0.0},
#  (4, 7): {<Action.UP: (0, 1)>: 0.0,
#   <Action.DOWN: (0, -1)>: 0.0,
#   <Action.LEFT: (-1, 0)>: 0.0,
#   <Action.RIGHT: (1, 0)>: 0.0},
#  (4, 8): {<Action.UP: (0, 1)>: 0.0,
#   <Action.DOWN: (0, -1)>: 0.0,
#   <Action.LEFT: (-1, 0)>: 0.0,
#   <Action.RIGHT: (1, 0)>: 0.0},
#  (4, 9): {<Action.DOWN: (0, -1)>: 0.0,
#   <Action.LEFT: (-1, 0)>: 0.0,
#   <Action.RIGHT: (1, 0)>: 0.0},
#  (5, 0): {<Action.UP: (0, 1)>: 0.0,
#   <Action.LEFT: (-1, 0)>: 0.0,
#   <Action.RIGHT: (1, 0)>: 0.0},
#  (5, 1): {<Action.UP: (0, 1)>: 0.0,
#   <Action.DOWN: (0, -1)>: 0.0,
#   <Action.LEFT: (-1, 0)>: 0.0,
#   <Action.RIGHT: (1, 0)>: 0.0},
#  (5, 2): {<Action.UP: (0, 1)>: 0.0,
#   <Action.DOWN: (0, -1)>: 0.0,
#   <Action.LEFT: (-1, 0)>: 0.0,
#   <Action.RIGHT: (1, 0)>: 0.0},
#  (5, 3): {<Action.UP: (0, 1)>: 0.0,
#   <Action.DOWN: (0, -1)>: 0.0,
#   <Action.LEFT: (-1, 0)>: 0.0,
#   <Action.RIGHT: (1, 0)>: 0.0},
#  (5, 4): {<Action.UP: (0, 1)>: 0.0,
#   <Action.DOWN: (0, -1)>: 0.0,
#   <Action.LEFT: (-1, 0)>: 0.0,
#   <Action.RIGHT: (1, 0)>: 0.0},
#  (5, 5): {<Action.UP: (0, 1)>: 0.0,
#   <Action.DOWN: (0, -1)>: 0.0,
#   <Action.LEFT: (-1, 0)>: 0.0,
#   <Action.RIGHT: (1, 0)>: 0.0},
#  (5, 6): {<Action.UP: (0, 1)>: 0.0,
#   <Action.DOWN: (0, -1)>: 0.0,
#   <Action.LEFT: (-1, 0)>: 0.0,
#   <Action.RIGHT: (1, 0)>: 0.0},
#  (5, 7): {<Action.UP: (0, 1)>: 0.0,
#   <Action.DOWN: (0, -1)>: 0.0,
#   <Action.LEFT: (-1, 0)>: 0.0,
#   <Action.RIGHT: (1, 0)>: 0.0},
#  (5, 8): {<Action.UP: (0, 1)>: 0.0,
#   <Action.DOWN: (0, -1)>: 0.0,
#   <Action.LEFT: (-1, 0)>: 0.0,
#   <Action.RIGHT: (1, 0)>: 0.0},
#  (5, 9): {<Action.DOWN: (0, -1)>: 0.0,
#   <Action.LEFT: (-1, 0)>: 0.0,
#   <Action.RIGHT: (1, 0)>: 0.0},
#  (6, 0): {<Action.UP: (0, 1)>: 0.0,
#   <Action.LEFT: (-1, 0)>: 0.0,
#   <Action.RIGHT: (1, 0)>: 0.0},
#  (6, 1): {<Action.UP: (0, 1)>: 0.0,
#   <Action.DOWN: (0, -1)>: 0.0,
#   <Action.LEFT: (-1, 0)>: 0.0,
#   <Action.RIGHT: (1, 0)>: 0.0},
#  (6, 2): {<Action.UP: (0, 1)>: 0.0,
#   <Action.DOWN: (0, -1)>: 0.0,
#   <Action.LEFT: (-1, 0)>: 0.0,
#   <Action.RIGHT: (1, 0)>: 0.0},
#  (6, 3): {<Action.UP: (0, 1)>: 0.0,
#   <Action.DOWN: (0, -1)>: 0.0,
#   <Action.LEFT: (-1, 0)>: 0.0,
#   <Action.RIGHT: (1, 0)>: 0.0},
#  (6, 4): {<Action.UP: (0, 1)>: 0.0,
#   <Action.DOWN: (0, -1)>: 0.0,
#   <Action.LEFT: (-1, 0)>: 0.0,
#   <Action.RIGHT: (1, 0)>: 0.0},
#  (6, 5): {<Action.UP: (0, 1)>: 0.0,
#   <Action.DOWN: (0, -1)>: 0.0,
#   <Action.LEFT: (-1, 0)>: 0.0,
#   <Action.RIGHT: (1, 0)>: 0.0},
#  (6, 6): {<Action.UP: (0, 1)>: 0.0,
#   <Action.DOWN: (0, -1)>: 0.0,
#   <Action.LEFT: (-1, 0)>: 0.0,
#   <Action.RIGHT: (1, 0)>: 0.0},
#  (6, 7): {<Action.UP: (0, 1)>: 0.0,
#   <Action.DOWN: (0, -1)>: 0.0,
#   <Action.LEFT: (-1, 0)>: 0.0,
#   <Action.RIGHT: (1, 0)>: 0.0},
#  (6, 8): {<Action.UP: (0, 1)>: 0.0,
#   <Action.DOWN: (0, -1)>: 0.0,
#   <Action.LEFT: (-1, 0)>: 0.0,
#   <Action.RIGHT: (1, 0)>: 0.0},
#  (6, 9): {<Action.DOWN: (0, -1)>: 0.0,
#   <Action.LEFT: (-1, 0)>: 0.0,
#   <Action.RIGHT: (1, 0)>: 0.0},
#  (7, 0): {<Action.UP: (0, 1)>: 0.0,
#   <Action.LEFT: (-1, 0)>: 0.0,
#   <Action.RIGHT: (1, 0)>: 0.0},
#  (7, 1): {<Action.UP: (0, 1)>: 0.0,
#   <Action.DOWN: (0, -1)>: 0.0,
#   <Action.LEFT: (-1, 0)>: 0.0,
#   <Action.RIGHT: (1, 0)>: 0.0},
#  (7, 2): {<Action.UP: (0, 1)>: 0.0,
#   <Action.DOWN: (0, -1)>: 0.0,
#   <Action.LEFT: (-1, 0)>: 0.0,
#   <Action.RIGHT: (1, 0)>: 0.0},
#  (7, 3): {<Action.UP: (0, 1)>: 0.0,
#   <Action.DOWN: (0, -1)>: 0.0,
#   <Action.LEFT: (-1, 0)>: 0.0,
#   <Action.RIGHT: (1, 0)>: 0.0},
#  (7, 4): {<Action.UP: (0, 1)>: 0.0,
#   <Action.DOWN: (0, -1)>: 0.0,
#   <Action.LEFT: (-1, 0)>: 0.0,
#   <Action.RIGHT: (1, 0)>: 0.0},
#  (7, 5): {<Action.UP: (0, 1)>: 0.0,
#   <Action.DOWN: (0, -1)>: 0.0,
#   <Action.LEFT: (-1, 0)>: 0.0,
#   <Action.RIGHT: (1, 0)>: 0.0},
#  (7, 6): {<Action.UP: (0, 1)>: 0.0,
#   <Action.DOWN: (0, -1)>: 0.0,
#   <Action.LEFT: (-1, 0)>: 0.0,
#   <Action.RIGHT: (1, 0)>: 0.0},
#  (7, 7): {<Action.UP: (0, 1)>: 0.0,
#   <Action.DOWN: (0, -1)>: 0.0,
#   <Action.LEFT: (-1, 0)>: 0.0,
#   <Action.RIGHT: (1, 0)>: 0.0},
#  (7, 8): {<Action.UP: (0, 1)>: 0.0,
#   <Action.DOWN: (0, -1)>: 0.0,
#   <Action.LEFT: (-1, 0)>: 0.0,
#   <Action.RIGHT: (1, 0)>: 0.0},
#  (7, 9): {<Action.DOWN: (0, -1)>: 0.0,
#   <Action.LEFT: (-1, 0)>: 0.0,
#   <Action.RIGHT: (1, 0)>: 0.0},
#  (8, 0): {<Action.UP: (0, 1)>: 0.0,
#   <Action.LEFT: (-1, 0)>: 0.0,
#   <Action.RIGHT: (1, 0)>: 0.0},
#  (8, 1): {<Action.UP: (0, 1)>: 0.0,
#   <Action.DOWN: (0, -1)>: 0.0,
#   <Action.LEFT: (-1, 0)>: 0.0,
#   <Action.RIGHT: (1, 0)>: 0.0},
#  (8, 2): {<Action.UP: (0, 1)>: 0.0,
#   <Action.DOWN: (0, -1)>: 0.0,
#   <Action.LEFT: (-1, 0)>: 0.0,
#   <Action.RIGHT: (1, 0)>: 0.0},
#  (8, 3): {<Action.UP: (0, 1)>: 0.0,
#   <Action.DOWN: (0, -1)>: 0.0,
#   <Action.LEFT: (-1, 0)>: 0.0,
#   <Action.RIGHT: (1, 0)>: 0.0},
#  (8, 4): {<Action.UP: (0, 1)>: 0.0,
#   <Action.DOWN: (0, -1)>: 0.0,
#   <Action.LEFT: (-1, 0)>: 0.0,
#   <Action.RIGHT: (1, 0)>: 0.0},
#  (8, 5): {<Action.UP: (0, 1)>: 0.0,
#   <Action.DOWN: (0, -1)>: 0.0,
#   <Action.LEFT: (-1, 0)>: 0.0,
#   <Action.RIGHT: (1, 0)>: 0.0},
#  (8, 6): {<Action.UP: (0, 1)>: 0.0,
#   <Action.DOWN: (0, -1)>: 0.0,
#   <Action.LEFT: (-1, 0)>: 0.0,
#   <Action.RIGHT: (1, 0)>: 0.0},
#  (8, 7): {<Action.UP: (0, 1)>: 0.0,
#   <Action.DOWN: (0, -1)>: 0.0,
#   <Action.LEFT: (-1, 0)>: 0.0,
#   <Action.RIGHT: (1, 0)>: 0.0},
#  (8, 8): {<Action.UP: (0, 1)>: 0.0,
#   <Action.DOWN: (0, -1)>: 0.0,
#   <Action.LEFT: (-1, 0)>: 0.0,
#   <Action.RIGHT: (1, 0)>: 0.0},
#  (8, 9): {<Action.DOWN: (0, -1)>: 0.0,
#   <Action.LEFT: (-1, 0)>: 0.0,
#   <Action.RIGHT: (1, 0)>: 0.0},
#  (9, 0): {<Action.UP: (0, 1)>: 0.0, <Action.LEFT: (-1, 0)>: 0.0},
#  (9, 1): {<Action.UP: (0, 1)>: 0.0,
#   <Action.DOWN: (0, -1)>: 0.0,
#   <Action.LEFT: (-1, 0)>: 0.0},
#  (9, 2): {<Action.UP: (0, 1)>: 0.0,
#   <Action.DOWN: (0, -1)>: 0.0,
#   <Action.LEFT: (-1, 0)>: 0.0},
#  (9, 3): {<Action.UP: (0, 1)>: 0.0,
#   <Action.DOWN: (0, -1)>: 0.0,
#   <Action.LEFT: (-1, 0)>: 0.0},
#  (9, 4): {<Action.UP: (0, 1)>: 0.0,
#   <Action.DOWN: (0, -1)>: 0.0,
#   <Action.LEFT: (-1, 0)>: 0.0},
#  (9, 5): {<Action.UP: (0, 1)>: 0.0,
#   <Action.DOWN: (0, -1)>: 0.0,
#   <Action.LEFT: (-1, 0)>: 0.0},
#  (9, 6): {<Action.UP: (0, 1)>: 0.0,
#   <Action.DOWN: (0, -1)>: 0.0,
#   <Action.LEFT: (-1, 0)>: 0.0},
#  (9, 7): {<Action.UP: (0, 1)>: 0.0,
#   <Action.DOWN: (0, -1)>: 0.0,
#   <Action.LEFT: (-1, 0)>: 0.0},
#  (9, 8): {<Action.UP: (0, 1)>: 0.0,
#   <Action.DOWN: (0, -1)>: 0.0,
#   <Action.LEFT: (-1, 0)>: 0.0},
#  (9, 9): {<Action.DOWN: (0, -1)>: 0.0, <Action.LEFT: (-1, 0)>: 0.0}}

# %%
from coord import Coord
def hoge(c):
    a = c(1,4)
    print(a.x, a.y)
hoge(Coord)
# Out:
# 1 4

# %%
from environment import Environment
f = Field()
e = Environment(QLearning, f)
# Out:
# True
